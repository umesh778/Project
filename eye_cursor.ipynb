# %%
# For monitoring web camera and performing image minipulations
import cv2
# For performing array operations
import numpy as np
# For creating and removing directories
import os
import shutil
# !pip install pynput
# For recognizing and performing actions on mouse presses
from pynput.mouse import Listener
# Out:
# Requirement already satisfied: pynput in c:\users\hp\.conda\envs\project\lib\site-packages (1.7.6)
# Requirement already satisfied: six in c:\users\hp\.conda\envs\project\lib\site-packages (from pynput) (1.16.0)

# %%
def normalize(x):
    minn, maxx = x.min(), x.max()
    return (x - minn) / (maxx - minn)

# %%
import cv2
# Load the cascade classifier detection object
cascade = cv2.CascadeClassifier("D:/project/haarcascade_eye.xml")
# Turn on the web camera
video_capture = cv2.VideoCapture(0)
# Read data from the web camera (get the frame)

# %%
def scan(image_size=(32, 32)):
    _, frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    boxes = cascade.detectMultiScale(gray, 1.3, 10)
    if len(boxes) == 2:
        eyes = []
        for box in boxes:
            x, y, w, h = box
            eye = frame[y:y + h, x:x + w]
            eye = cv2.resize(eye, image_size)
            eye = normalize(eye)
            eye = eye[10:-10, 5:-5]
            eyes.append(eye)
        return (np.hstack(eyes) * 255).astype(np.uint8)
    else:
        return None

# %%
import cv2
from pynput.mouse import Listener
def on_click(x, y, button, pressed):
    if pressed:
        print (x, y,button)
        video_capture = cv2.VideoCapture(0)
        root="D:/project/eye_pics/"
        eyes = scan()
        # If the function returned None, something went wrong
        if not eyes is None:
            print("sorry")
            # Save the image
            filename = root + "{} {} {}.jpeg".format(x, y, button)
            cv2.imwrite(filename, eyes)
        
with Listener(on_click = on_click) as listener:
    listener.join()
# Out:
# 104 450 Button.left
# 713 230 Button.left
# 119 173 Button.left
# sorry
# 126 598 Button.left
# sorry
# 1777 204 Button.left
# sorry
# 1262 142 Button.left
# sorry
# 1169 137 Button.left
# sorry
# 1016 135 Button.left
# sorry
# 123 713 Button.left
# sorry
# 104 908 Button.left
# 61 969 Button.left
# 0 880 Button.left
# sorry
# 53 878 Button.left
# 14 779 Button.left
# sorry
# 57 732 Button.left
# sorry
# 38 619 Button.left
# sorry
# 27 548 Button.left
# sorry
# 28 494 Button.left
# sorry
# 63 437 Button.left
# sorry
# 206 360 Button.left
# sorry
# 1048 380 Button.left
# sorry
# 1292 376 Button.left
# sorry
# 1513 385 Button.left
# sorry
# 1642 376 Button.left
# sorry
# 1781 377 Button.left
# sorry
# 1779 539 Button.left
# sorry
# 1749 205 Button.left
# sorry
# 1241 144 Button.left
# sorry
# 1166 149 Button.left
# sorry
# 1415 152 Button.left
# sorry
# 1044 142 Button.left
# sorry
# 22 144 Button.left
# sorry
# 89 155 Button.left
# sorry
# 120 161 Button.left
# sorry
# 164 160 Button.left
# sorry
# 195 163 Button.left
# sorry
# 235 164 Button.left
# sorry
# 236 195 Button.left
# sorry
# 172 199 Button.left
# sorry
# 117 195 Button.left
# sorry
# 75 195 Button.left
# sorry
# 10 195 Button.left
# 27 309 Button.left
# sorry
# 54 285 Button.left
# sorry
# 21 365 Button.left
# sorry
# 37 208 Button.left
# sorry
# 114 223 Button.left
# sorry
# 162 223 Button.left
# sorry
# 202 291 Button.left
# sorry
# 197 365 Button.left
# sorry
# 193 492 Button.left
# sorry
# 181 571 Button.left
# sorry
# 411 584 Button.left
# sorry
# 710 506 Button.left
# sorry
# 640 413 Button.left
# sorry
# 663 395 Button.left
# sorry
# 804 391 Button.left
# sorry
# 1023 427 Button.left
# sorry
# 1190 439 Button.left
# sorry
# 1099 562 Button.left
# sorry
# 721 527 Button.left
# sorry
# 1049 536 Button.left
# sorry
# 787 487 Button.left
# sorry
# 919 458 Button.left
# sorry
# 741 424 Button.left
# sorry
# 1116 401 Button.left
# sorry
# 709 405 Button.left
# sorry
# 867 725 Button.left
# sorry
# 962 730 Button.left
# sorry
# 1048 731 Button.left
# sorry
# 710 735 Button.left
# sorry
# 892 204 Button.left
# sorry
# 854 198 Button.left
# sorry
# 760 194 Button.left
# sorry
# 946 201 Button.left
# sorry
# 1027 200 Button.left
# sorry
# 1109 197 Button.left
# sorry
# 1183 201 Button.left
# sorry
# 1149 152 Button.left
# sorry
# 769 117 Button.left
# sorry
# 761 116 Button.left
# sorry
# 707 110 Button.left
# sorry
# 739 114 Button.left
# sorry
# 609 114 Button.left
# sorry
# 661 119 Button.left
# sorry
# 633 145 Button.left
# sorry
# 633 146 Button.left
# sorry
# 715 150 Button.left
# sorry
# 789 145 Button.left
# sorry
# 867 152 Button.left
# sorry
# 919 158 Button.left
# sorry
# 1000 163 Button.left
# sorry
# 1059 165 Button.left
# sorry
# 533 47 Button.left
# sorry
# 596 53 Button.left
# sorry
# 646 57 Button.left
# sorry
# 702 57 Button.left
# sorry
# 750 59 Button.left
# sorry
# 799 59 Button.left
# sorry
# 909 58 Button.right
# sorry
# 996 62 Button.right
# sorry
# 1060 51 Button.right
# sorry
# 1110 60 Button.right
# sorry
# 1244 60 Button.right
# sorry
# 1315 54 Button.right
# sorry
# 189 15 Button.right
# sorry
# 477 36 Button.right
# sorry
# 527 66 Button.left
# sorry
# 371 61 Button.left
# sorry
# 359 40 Button.left
# sorry
# 315 29 Button.left
# sorry
# 404 34 Button.left
# sorry
# 496 40 Button.left
# sorry
# 541 33 Button.left
# 541 33 Button.left
# sorry
# 712 35 Button.left
# sorry
# 616 42 Button.left
# sorry
# 634 279 Button.left
# sorry
# 757 233 Button.left
# sorry
# 927 254 Button.left
# sorry
# 1043 249 Button.left
# sorry
# 1155 245 Button.left
# sorry
# 1259 256 Button.left
# sorry
# 1368 243 Button.left
# sorry
# 1544 245 Button.left
# sorry
# 1721 252 Button.left
# sorry
# 1732 477 Button.left
# sorry
# 1632 516 Button.left
# sorry
# 1466 482 Button.left
# sorry
# 840 367 Button.left
# sorry
# 637 339 Button.left
# sorry
# 358 134 Button.left
# sorry
# 413 318 Button.left
# sorry
# 555 313 Button.left
# sorry
# 531 135 Button.left
# sorry
# 438 347 Button.left
# sorry
# 570 358 Button.left
# sorry
# 622 342 Button.left
# sorry
# 361 138 Button.left
# sorry
# 531 472 Button.left
# sorry
# 533 350 Button.left
# sorry
# 683 332 Button.right
# sorry
# 909 386 Button.right
# sorry
# 718 276 Button.right
# sorry
# 334 317 Button.left
# sorry
# 349 424 Button.left
# sorry
# 286 533 Button.left
# sorry
# 252 312 Button.left
# sorry
# 303 410 Button.left
# sorry
# 513 317 Button.left
# sorry
# 72 290 Button.left
# sorry
# 229 302 Button.left
# sorry
# 325 300 Button.left
# sorry
# 565 324 Button.left
# sorry
# 149 131 Button.left
# sorry
# 244 103 Button.left
# sorry
# 192 133 Button.left
# sorry
# 223 36 Button.left
# sorry
# 339 102 Button.left
# sorry
# 398 119 Button.left
# sorry
# 460 133 Button.left
# sorry
# 426 21 Button.left
# sorry
# 191 12 Button.left
# sorry
# 300 21 Button.left
# sorry
# 418 16 Button.left
# sorry
# 480 64 Button.left
# sorry
# 594 74 Button.left
# 703 39 Button.left
# sorry
# 793 58 Button.left
# sorry
# 748 157 Button.left
# sorry
# 688 320 Button.left
# sorry
# 792 492 Button.left
# sorry
# 978 539 Button.left
# sorry
# 1033 713 Button.left
# sorry
# 355 186 Button.left
# sorry
# 590 561 Button.left
# sorry
# 726 605 Button.left
# sorry
# 858 501 Button.left
# sorry
# 980 499 Button.left
# sorry
# 1149 580 Button.left
# sorry
# 1049 462 Button.left
# sorry
# 997 450 Button.left
# sorry
# 934 436 Button.left
# sorry
# 896 376 Button.left
# sorry
# 949 382 Button.left
# sorry
# 1021 385 Button.left
# sorry
# 988 397 Button.left
# sorry
# 980 359 Button.left
# sorry
# 901 358 Button.left
# sorry
# 924 426 Button.left
# sorry
# 934 373 Button.left
# sorry
# 910 370 Button.left
# sorry
# 931 361 Button.left
# sorry
# 946 364 Button.left
# sorry
# 953 344 Button.left
# sorry
# 877 319 Button.left
# sorry
# 748 352 Button.left
# sorry
# 792 307 Button.left
# sorry
# 760 327 Button.left
# sorry
# 778 380 Button.left
# sorry
# 777 333 Button.left
# sorry
# 794 350 Button.left
# 605 295 Button.left
# sorry
# 601 317 Button.left
# sorry
# 618 337 Button.left
# sorry
# 654 299 Button.left
# sorry
# 631 331 Button.left
# sorry
# 624 369 Button.left
# sorry
# 615 399 Button.left
# sorry
# 606 448 Button.left
# sorry
# 604 471 Button.left
# sorry
# 604 497 Button.left
# sorry
# 615 555 Button.left
# sorry
# 642 545 Button.left
# sorry
# 698 524 Button.left
# sorry
# 717 513 Button.left
# sorry
# 762 477 Button.left
# sorry
# 763 466 Button.left
# sorry
# 747 516 Button.left
# sorry
# 752 433 Button.left
# sorry
# 761 448 Button.left
# sorry
# 696 353 Button.left
# sorry
# 686 337 Button.left
# sorry
# 707 364 Button.left
# sorry
# 715 377 Button.left
# sorry
# 727 390 Button.left
# sorry
# 734 409 Button.left
# sorry
# 617 311 Button.left
# sorry
# 659 328 Button.left
# sorry
# 645 359 Button.left
# sorry
# 638 398 Button.left
# sorry
# 651 419 Button.left
# sorry
# 669 409 Button.left
# sorry
# 679 385 Button.left
# sorry
# 654 397 Button.left
# sorry
# 640 371 Button.left
# sorry
# 663 351 Button.left
# sorry
# 658 374 Button.left
# sorry
# 672 339 Button.left
# sorry
# 698 380 Button.left
# sorry
# 676 426 Button.left
# sorry
# 690 425 Button.left
# sorry
# 638 419 Button.left
# sorry
# 623 452 Button.left
# sorry
# 640 441 Button.left
# sorry
# 650 441 Button.left
# sorry
# 695 443 Button.left
# sorry
# 740 447 Button.left
# sorry
# 746 449 Button.left
# sorry
# 648 466 Button.left
# sorry
# 701 473 Button.left
# sorry
# 716 473 Button.left
# sorry
# 609 357 Button.left
# 579 336 Button.left
# 596 336 Button.left
# 693 291 Button.left
# sorry
# 705 338 Button.left
# sorry
# 741 328 Button.left
# sorry
# 718 325 Button.left
# sorry
# 722 336 Button.left
# sorry
# 719 284 Button.left
# sorry
# 695 302 Button.left
# sorry
# 668 292 Button.left
# sorry
# 680 299 Button.left
# sorry
# 788 300 Button.left
# sorry
# 840 300 Button.left
# sorry
# 882 302 Button.left
# sorry
# 960 305 Button.left
# sorry
# 1044 307 Button.left
# sorry
# 1148 311 Button.left
# sorry
# 286 614 Button.left
# sorry
# 251 663 Button.left
# sorry
# 273 711 Button.left
# sorry
# 343 766 Button.left
# sorry
# 438 744 Button.left
# sorry
# 467 713 Button.left
# sorry
# 440 666 Button.left
# sorry
# 372 582 Button.left
# sorry
# 310 603 Button.left
# sorry
# 309 599 Button.left
# sorry
# 355 609 Button.left
# sorry
# 351 632 Button.left
# sorry
# 403 648 Button.left
# sorry
# 359 652 Button.left
# sorry
# 386 634 Button.left
# sorry
# 436 685 Button.left
# sorry
# 406 670 Button.left
# sorry
# 415 677 Button.left
# sorry
# 308 625 Button.left
# sorry
# 298 634 Button.left
# sorry
# 299 648 Button.left
# sorry
# 238 666 Button.left
# sorry
# 274 660 Button.left
# sorry
# 286 660 Button.left
# sorry
# 300 716 Button.left
# sorry
# 341 718 Button.left
# sorry
# 374 720 Button.left
# sorry
# 419 720 Button.left
# sorry
# 389 704 Button.left
# sorry
# 383 688 Button.left
# sorry
# 402 706 Button.left
# sorry
# 439 706 Button.left
# sorry
# 401 705 Button.left
# sorry
# 414 706 Button.left
# sorry
# 318 721 Button.left
# sorry
# 346 754 Button.left
# sorry
# 392 739 Button.left
# sorry
# 456 749 Button.left
# sorry
# 398 780 Button.left
# sorry
# 326 739 Button.left
# sorry
# 256 710 Button.left
# sorry
# 314 727 Button.left
# sorry
# 421 767 Button.left
# 472 832 Button.left
# 435 816 Button.left
# 369 761 Button.left
# 359 742 Button.left
# 313 719 Button.left
# 256 678 Button.left
# 408 560 Button.left
# 439 570 Button.left
# 399 601 Button.left
# 424 524 Button.left
# sorry
# 456 532 Button.left
# sorry
# 403 635 Button.left
# sorry
# 431 573 Button.left
# sorry
# 473 570 Button.left
# 425 595 Button.left
# sorry
# 452 564 Button.left
# sorry
# 420 539 Button.left
# sorry
# 428 533 Button.left
# sorry
# 442 523 Button.left
# sorry
# 365 514 Button.left
# sorry
# 391 580 Button.left
# sorry
# 388 527 Button.left
# sorry
# 370 564 Button.left
# sorry
# 382 544 Button.left
# sorry
# 346 525 Button.left
# sorry
# 346 524 Button.left
# sorry
# 395 524 Button.left
# sorry
# 490 540 Button.left
# sorry
# 564 551 Button.left
# sorry
# 651 565 Button.left
# sorry
# 478 546 Button.left
# sorry
# 476 621 Button.left
# sorry
# 573 627 Button.left
# sorry
# 539 641 Button.left
# sorry
# 652 621 Button.left
# sorry
# 152 277 Button.left
# sorry
# 155 344 Button.left
# 49 482 Button.left
# sorry
# 56 303 Button.left
# sorry
# 106 303 Button.left
# sorry
# 137 344 Button.left
# 62 351 Button.left
# sorry
# 125 362 Button.left
# sorry
# 109 368 Button.left
# 74 344 Button.left
# sorry
# 64 396 Button.left
# sorry
# 82 369 Button.left
# 81 388 Button.left
# sorry
# 107 386 Button.left
# sorry
# 127 383 Button.left
# sorry
# 123 406 Button.left
# sorry
# 99 400 Button.left
# sorry
# 69 445 Button.left
# sorry
# 77 439 Button.left
# sorry
# 109 446 Button.left
# sorry
# 82 452 Button.left
# sorry
# 67 464 Button.left
# sorry
# 105 418 Button.left
# sorry
# 127 449 Button.left
# sorry
# 137 507 Button.left
# sorry
# 50 514 Button.left
# 118 521 Button.left
# 149 530 Button.left
# sorry
# 68 521 Button.left
# 116 550 Button.left
# sorry
# 56 546 Button.left
# 82 552 Button.left
# 156 545 Button.left
# sorry
# 148 589 Button.left
# 161 616 Button.left
# 164 592 Button.left
# 164 656 Button.left
# 137 660 Button.left
# 144 686 Button.left
# 148 671 Button.left
# 101 568 Button.left
# 109 578 Button.left
# 107 610 Button.left
# 89 616 Button.left
# 52 580 Button.left
# 50 640 Button.left
# 102 656 Button.left
# 120 625 Button.left
# 30 695 Button.left
# 57 623 Button.left
# 94 596 Button.left
# 52 713 Button.left
# 112 702 Button.left
# 53 698 Button.left
# 74 668 Button.left
# sorry
# 110 671 Button.left
# sorry
# 79 618 Button.left
# 93 638 Button.left
# 50 762 Button.left
# sorry
# 184 683 Button.left
# sorry
# 51 777 Button.left
# 79 763 Button.left
# sorry
# 69 786 Button.left
# sorry
# 126 773 Button.left
# sorry
# 170 729 Button.left
# sorry
# 105 760 Button.left
# sorry
# 51 815 Button.left
# sorry
# 51 875 Button.left
# 52 829 Button.left
# sorry
# 59 810 Button.left
# sorry
# 55 851 Button.left
# sorry
# 67 830 Button.left
# sorry
# 100 820 Button.left
# 136 798 Button.left
# sorry
# 172 760 Button.left
# sorry
# 151 786 Button.left
# sorry
# 165 784 Button.left
# 147 806 Button.left
# sorry
# 184 847 Button.left
# 243 873 Button.left
# sorry
# 152 879 Button.left
# sorry
# 200 849 Button.left
# sorry
# 144 835 Button.left
# 104 837 Button.left
# sorry
# 106 866 Button.left
# sorry
# 62 890 Button.left
# 82 891 Button.left
# 56 914 Button.left
# sorry
# 84 919 Button.left
# 139 898 Button.left
# sorry
# 171 881 Button.left
# sorry
# 180 867 Button.left
# sorry
# 221 898 Button.left
# sorry
# 183 896 Button.left
# sorry
# 156 961 Button.left
# 211 950 Button.left
# sorry
# 157 907 Button.left
# 182 906 Button.left
# sorry
# 201 909 Button.left
# sorry
# 165 922 Button.left
# sorry
# 245 904 Button.left
# 240 923 Button.left
# sorry
# 258 889 Button.left
# sorry
# 281 906 Button.left
# 311 923 Button.left
# 280 923 Button.left
# 201 809 Button.left
# 194 302 Button.left
# sorry
# 223 324 Button.left
# sorry
# 171 386 Button.left
# sorry
# 265 496 Button.left
# sorry
# 354 452 Button.left
# sorry
# 411 286 Button.left
# sorry
# 209 438 Button.left
# sorry
# 297 403 Button.left
# sorry
# 391 379 Button.left
# sorry
# 330 338 Button.left
# sorry
# 255 368 Button.left
# 237 393 Button.left
# sorry
# 199 314 Button.left
# sorry
# 200 305 Button.left
# sorry
# 280 312 Button.left
# sorry
# 423 305 Button.left
# 196 340 Button.left
# sorry
# 268 356 Button.left
# sorry
# 349 383 Button.left
# sorry
# 199 362 Button.left
# sorry
# 192 428 Button.right
# sorry
# 267 380 Button.right
# sorry
# 318 456 Button.left
# sorry
# 212 426 Button.right
# sorry
# 214 424 Button.right
# sorry
# 214 423 Button.right
# sorry
# 217 419 Button.left
# sorry
# 250 400 Button.right
# sorry
# 250 400 Button.left
# sorry
# 253 390 Button.left
# sorry
# 254 389 Button.left
# sorry
# 190 414 Button.left
# sorry
# 185 450 Button.right
# sorry
# 222 459 Button.right
# sorry
# 548 404 Button.left
# sorry
# 162 443 Button.left
# sorry
# 192 473 Button.left
# sorry
# 167 398 Button.left
# 286 438 Button.left
# sorry
# 238 463 Button.left
# sorry
# 198 413 Button.left
# sorry
# 247 293 Button.left
# sorry
# 362 357 Button.left
# sorry
# 310 439 Button.left
# sorry
# 303 365 Button.left
# sorry
# 409 371 Button.left
# sorry
# 376 407 Button.left
# sorry
# 301 448 Button.left
# sorry
# 411 402 Button.left
# 723 26 Button.left
# 762 654 Button.left
# 1020 3 Button.left
# 360 218 Button.left
# 1412 440 Button.left

# %%
video_capture.release()
cv2.destroyAllWindows()
